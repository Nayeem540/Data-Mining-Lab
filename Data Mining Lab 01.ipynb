# %%
print("Md. Nayeem Sarker")
# Out:
# Md. Nayeem Sarker

# %%
x = "Bangladesh"
print(x)
# Out:
# Bangladesh

# %%
f_name = "Nayeem"
l_name = "Sarker"
full_name = f_name + " " + l_name
print(full_name)
# Out:
# Nayeem Sarker

# %%
x = str(5)
y = int(5)
z = float(3)

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
name = '''Md. Nayeem
Sarker'''
print(name)
# Out:
# Md. Nayeem Sarker

# %%
name = input("Enter your name: ")
print("Hello " + name )

age = input("Enter your age: ")
print("Your age is " + age)
# Out:
# Enter your name: Md. Nayeem Sarker
# Hello Md. Nayeem Sarker
# Enter your age: 26
# Your age is 26

# %%
age = int(input("Enter your age: "))
print("Your age is ", age)
# Out:
# Enter your age: 26
# Your age is  26

# %%
#print(5/0)
print(9//3)
print(10/5)
# Out:
# 3
# 2.0

# %%
r = int(input("Enter radius: "))
area = 3.1416*r**2
print(area)
# Out:
# Enter radius: 3
# 28.2744

# %%
x = 10
print(x < 5 and x < 10)
print(x<10)
# Out:
# False
# False

# %%
a = 7
print(a > 3 and a!=5)
# Out:
# True
